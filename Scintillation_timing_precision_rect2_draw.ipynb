# %% [markdown]
# <h1>Draw timing precision comparison for small rectangular prism for PET</h1>
#
# Data produced by <b>Scintillation_timing_precision_rect2.ipynb</b>.

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.ticker import ScalarFormatter
import pickle

# %%
# %load_ext autoreload
# %autoreload 2

# %%
result= pickle.load(open('../data/timing/tprecision_rect_preamp_geocolls2.p'))

# %%
print result.keys()
# Out:
# ['csira3:SL-APD3mm', 'lysopo3:SL-APD3mm_err', 'baf2ra1:SL-APD3mm_err', 'csipo1:SL-APD3mm', 'lysora2:SL-APD3mm', 'lysora3:SL-APD3mm', 'lysopo2:SL-APD3mm_err', 'lysora2:SL-APD3mm_err', 'baf2po1:SL-APD3mm', 'baf2po2:SL-APD3mm', 'csipo3:SL-APD3mm_err', 'lysora3:SL-APD3mm_err', 'lysopo2:SL-APD3mm', 'baf2ra2:SL-APD3mm', 'lysora1:SL-APD3mm', 'csira1:SL-APD3mm_err', 'csipo2:SL-APD3mm_err', 'baf2ra2:SL-APD3mm_err', 'csira1:SL-APD3mm', 'csira2:SL-APD3mm', 'lysora1:SL-APD3mm_err', 'lysopo3:SL-APD3mm', 'baf2po2:SL-APD3mm_err', 'csipo2:SL-APD3mm', 'lysopo1:SL-APD3mm', 'csira2:SL-APD3mm_err', 'csipo3:SL-APD3mm', 'baf2ra3:SL-APD3mm_err', 'baf2po3:SL-APD3mm', 'lysopo1:SL-APD3mm_err', 'baf2po3:SL-APD3mm_err', 'baf2po1:SL-APD3mm_err', 'baf2ra3:SL-APD3mm', 'npelist', 'csipo1:SL-APD3mm_err', 'baf2ra1:SL-APD3mm', 'csira3:SL-APD3mm_err']

# %%
cnames=dict(lyso='LYSO', baf2='BaF2', csi='CsI')
apdname= 'SL-APD3mm'

# %%
def figform(ax):
    plt.xscale('log')
    plt.yscale('log')
    plt.xlim(5, 50000)
    plt.ylim(3, 30000)
    plt.legend()
    plt.grid(which='major')
    plt.grid(which='minor')
    plt.xlabel('Number of photoelectrons', fontsize='x-large')
    plt.ylabel('Precision (ps)', fontsize='x-large')
    ax.get_xaxis().set_major_formatter(ScalarFormatter())
    ax.get_yaxis().set_major_formatter(ScalarFormatter())

# %% [markdown]
# <h2>Polished crystals</h2>

# %%
fig= plt.figure(figsize=(10,7))
ax = fig.add_subplot(111)

colors=['b','r','g']
markers=['o','s','^']

dkeys=[]
for mat,cl in zip(['lyso','baf2','csi'],colors):
    for lg,mk in zip([1,2,3],markers):
        key= '%s%s%d:%s'%(mat,'po',lg, apdname)
        dkeys.append(key)
        plt.errorbar(result['npelist'], result[key]*1e3, result[key+'_err']*1e3, 
                     fmt= '-', color=cl, mec='k', mew=1, ms=7, marker=mk, mfc=cl, label='%s:%d cm'%(cnames[mat],lg), alpha=0.7)
print dkeys
figform(ax)
# Out:
# ['lysopo1:SL-APD3mm', 'lysopo2:SL-APD3mm', 'lysopo3:SL-APD3mm', 'baf2po1:SL-APD3mm', 'baf2po2:SL-APD3mm', 'baf2po3:SL-APD3mm', 'csipo1:SL-APD3mm', 'csipo2:SL-APD3mm', 'csipo3:SL-APD3mm']

# %%
fig.savefig('../plots/timing_dependence_on_pe_rectcolls2_pol.pdf')

# %% [markdown]
# <h2>Roughened crystals</h2>

# %%
fig= plt.figure(figsize=(10,7))
ax = fig.add_subplot(111)

colors=['b','r','g']
markers=['o','s','^']

for mat,cl in zip(['lyso','baf2','csi'],colors):
    for lg,mk in zip([1,2,3],markers):
        key= '%s%s%d:%s'%(mat,'ra',lg, apdname)
        dkeys.append(key)
        plt.errorbar(result['npelist'], result[key]*1e3, result[key+'_err']*1e3, 
                     fmt= '-', color=cl, mec='k', mew=1, ms=7, marker=mk, mfc=cl, label='%s:%d cm'%(cnames[mat],lg), alpha=0.7)
figform(ax)

# %%
fig.savefig('../plots/timing_dependence_on_pe_rectcolls2_ruf.pdf')

# %% [markdown]
# <h2>Fit a power law dependence</h2>
#
# $p(N) = B \cdot (N/100)^a$

# %%
from fit_utilities import *

# %%
Bfactors= {}
apowers= {}
Bferrors= {}
aperrors= {}

# %%
# Do fits here
for key in dkeys:
    # Ignore the first two points
    npe100= np.array(result['npelist'][2:])/100.0  # number of photoelectrons in multiple of 100
    rmsps= result[key][2:]*1e3   # precision in picoseconds
    error= result[key+'_err'][2:]*1e3 # error in picoseconds  ##/result[key][2:]
    values, errors = fit_power_lawab(npe100, rmsps, error)
    Bfactors[key] = values['b']
    Bferrors[key] = errors['b']
    apowers[key] = values['a']
    aperrors[key] = errors['a']

# %%
print cnames
# Out:
# {'baf2': 'BaF2', 'csi': 'CsI', 'lyso': 'LYSO'}

# %%
def print_table(d, e, digits=0):
    print '%4s'%'',
    print '%10s%10s%10s'%('1 cm','2 cm', '3 cm'),
    print
    fmt = ' & $%%.%df\\pm%%.%df$'%(digits,digits)
    for mat in ['baf2','lyso','csi']:
        print '%4s'%cnames[mat],
        for tag in ['po1','po2','po3']:
            key= '%s%s:%s'%(mat,tag, apdname)
            print fmt%(d[key],e[key]),
        print

# %% [markdown]
# The $B$ factor in $p(N) = B \cdot (N/100)^a$

# %%
print_table(Bfactors, Bferrors, digits=1)
# Out:
#            1 cm      2 cm      3 cm
# BaF2  & $72.6\pm1.2$  & $76.6\pm1.3$  & $78.1\pm1.3$
# LYSO  & $1002.2\pm17.5$  & $1030.8\pm17.8$  & $1012.3\pm17.5$
#  CsI  & $830.8\pm14.3$  & $846.9\pm14.7$  & $812.6\pm14.1$

# %% [markdown]
# The power $a$.

# %%
print_table(apowers, aperrors, digits=3)
# Out:
#            1 cm      2 cm      3 cm
# BaF2  & $-0.499\pm0.006$  & $-0.503\pm0.006$  & $-0.496\pm0.006$
# LYSO  & $-0.498\pm0.006$  & $-0.509\pm0.006$  & $-0.507\pm0.006$
#  CsI  & $-0.502\pm0.006$  & $-0.511\pm0.006$  & $-0.498\pm0.006$

# %%
np.power(2,3)
# Out:
# 8
