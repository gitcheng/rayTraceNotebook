# %% [markdown]
# <h1>Scintillation timing waveform fit precision for hexagonal-cross-section crystal bars</h1>

# %% [markdown]
# * Use data produced by <b><code>scripts/time\_geom2\_hex\_*.py</code></b>
# * Geometry defined in <b><code>geometry_collection_2</code></b>
# * See more detail in <b><code>Scintillation_timing_precision_hex2</code></b>

# %% [markdown]
# <h2>Waveform fit</h2>
#
# After an event pulse is formed (see Scintillation_timing_precision_hex2), we sample the pulse into a digitized waveform. The sampling frequency is possibly a few hundred MHz, that is, the interval is a few ns. We test a few different intervals to show the effect on the interval.
#
# The waveform is then fit with a model, $A(t) = e^{-(t-t_0)/\tau_d}-e^{-(t-t_0)/\tau_r}$ convolved with a Gaussian. The range of the fit is to be optimized. The time shift parameter $t_0$ is approximately the time the curve crosses 50% (?) of the maximum. We simulate a number (1000) of signals in each setting, sample the waveform with a random starting time of the bins, then fit for the model. We record all parameters in each fit. The distribution of $t_0$ can be viewed as the timing precision. We can also reconstruct the function and examine the distribution of the time a curve reaches 10% of the maximum, which may have a better precision.

# %% [markdown]
# The pdf function of an exponential convolved with a Gaussian can be expressed as
#
# $\begin{equation}
# G_{\rm exp}(t; \sigma, \tau) = \frac{1}{2\tau} e^{\sigma^2/2\tau^2}\left[ 1- {\rm erf}(\frac{-t}{\sqrt{2}\sigma} + \frac{\sigma}{\sqrt{2}\tau})\right]
# \end{equation}$
#
# Therefore, the function $A(t)$ convolved with a Gaussian is
#
# $\begin{equation}
# B(t; t_0, \sigma, \tau_1, \tau_2) = \frac{1}{\tau_1-\tau_2}\left[\tau_1 G_{\rm exp}(t-t_0, \sigma, \tau_1)- \tau_2 G_{\rm exp}(t-t_0, \sigma, \tau_2) \right]
# \end{equation}$

# %% [markdown]
# <h2> Sample </h2>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np
rand = np.random
from timing_utilities import *
from geometry_collection_2 import *
from gen_utilities import *
from fit_utilities import *
import pickle

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# <h2>Geometry</h2>
#
# Three crystals: BaF2, LYSO, and CsI bars with a hexagonal cross section. The length is approximately proportional to the radiation length. The cross sections are the same for all three crystals.
#
# Defined in geometry_collection_2.py
#
# Length: BaF2 20 cm; LYSO 11 cm;  CsI 19 cm.<br>
# Width of the hexagon (distance between opposite parallel edges)= 3.3 cm.
#
# Sensors: two 9 mm X 9 mm photosensors (ignore 3x3 case).

# %%
fig= plt.figure(figsize=(9,10))
cnames=dict(lyso='LYSO', baf2='BaF2', csi='CsI')
i=0
for mat in ['lyso','baf2','csi']:
    for sd in ['9']:
        key = mat+'po'+sd
        ax = fig.add_subplot(131+i, projection='3d')
        ax.set_title(cnames[mat])
        draw_one_crystal(ax, chexes[key])
        i+= 1

# %%
# The timing population to sample from
# Only need polished, 9x9
hexdata= {}
for mat in ['lyso','baf2','csi']:
    for sur in ['po']:
        for sd in ['9']:
            key= mat+sur+sd
            filename= '../data/timing/time_geom2_hex_%s.npy'%(key)
            data = np.load(filename).view(np.recarray)
            hexdata[key]= data
            print '%s population : %d'%(key,len(data))
# Out:
# lysopo9 population : 39591
# baf2po9 population : 45815
# csipo9 population : 30868

# %% [markdown]
# <h2>APD pulse model</h2>

# %%
slapd9mm = pulse_model('../data/SLAPD_RiseTime_20140926.csv', 'time_ns', 'slapd9mm', normtype='peak')
# Fill in points using linear interpolation
slapd9mm = fill_pmodel_gaps(slapd9mm, ndivs=5)
# t>=0
slapd9mm = slapd9mm[slapd9mm.t>0]

# %%
t= slapd9mm.t
ps= pulse_shape_simple(t, 6.0, 15.0, 1.0)
pream= np.array(zip(t,ps), dtype=slapd9mm.dtype).view(np.recarray)
plt.plot(pream.t, pream.p)
plt.title('Preamp model');
plt.xlabel('ns');

# %%
pmslapd9mm= convolve_two_pulse_model(slapd9mm, pream)

# %%
plt.plot(pmslapd9mm.t, pmslapd9mm.p/pmslapd9mm.p.max(), label='SL-APD 9mm');
plt.xlim(0,200)
plt.ylim(-0.2,1.1)
plt.plot([0,200],[0,0], 'k-')
plt.legend()
plt.xlabel('ns');
plt.title('APD+Preamp response time');

# %% [markdown]
# <h2>Event pulse samples</h2>
#
# Draw a pulse shapes for a few events. We assume the photoelectron ratio is BaF2:LYSO:CsI = 1: 20: 1.

# %%
## Scintillator decay time
tau_baf2 = 0.9
tau_lyso = 40
tau_csi = 30
## photoelectrons for these samples
npe_baf2 = 1000
npe_lyso = 20000
npe_csi = 1000

# %%
def draw_waveform(ax, event, title=None, **kwargs):
    bins= make_bins(event.t)
    ax.hist(event.t, bins=bins, weights=event.p, **kwargs)
    ax.plot([event.t.min(),event.t.max()],[0,0], 'k-')
    ax.set_xlim(event.t.min(), event.t.max())
    if title is not None:
        ax.set_title(title)
    ax.set_xlabel('ns')
    ax.set_ylabel('Arbitrary unit')
    ax.grid()

# %%
def draw_one_set(ax, dtpop, scinttau, npe0, pulsemodel, title):
    draw_pulse_samples(ax, dtpop, npe0= npe0, scinttau= scinttau, jittersigma= 0.1, noise= 0, pulsemodel= pulsemodel, n=20,
                       color='b', alpha=0.2)
    ax.set_title(title)

# %%
tbaf29mm = event_pulse(hexdata['baf2po9'].t, npe_baf2, tau_baf2, 0.1, 0, pmslapd9mm)
tlyso9mm = event_pulse(hexdata['lysopo9'].t, npe_lyso, tau_lyso, 0.1, 0, pmslapd9mm)
tcsi9mm = event_pulse(hexdata['csipo9'].t, npe_csi, tau_csi, 0.1, 0, pmslapd9mm)

# %%
wfbaf29mm5ns = digiwaveform(tbaf29mm, 5.0)
wflyso9mm5ns = digiwaveform(tlyso9mm, 5.0)
wfcsi9mm5ns = digiwaveform(tcsi9mm, 5.0)

# %%
fig= plt.figure(figsize=(18,4))
ax= fig.add_subplot(131)
draw_waveform(ax, wfbaf29mm5ns, title='BaF2', histtype='step')
ax= fig.add_subplot(132)
draw_waveform(ax, wflyso9mm5ns, title='LYSO', histtype='step')
ax= fig.add_subplot(133)
draw_waveform(ax, wfcsi9mm5ns, title='CsI', histtype='step')
fig.savefig('../plots/waveform_9mm5ns.pdf')

# %%
def waveformfit(wf, fitrange=None):
    '''
    *wf*: waveform
    *fitrange* is the total range of the fit centered at the estimated time over 50% maximum threshold
    '''
    # t reaching half maximum, used for initial value of x0
    t50 = time_reach_threshold(wf.t, wf.p, 0.5)
    tmax = wf.t[wf.p.argmax()]
    # estimate integral
    bins = make_bins(wf.t)
    bw= bins[1:]-bins[:-1]
    intl= float((wf.p*bw).sum())
    
    if fitrange is not None:
        sel = (wf.t>=t50-fitrange/2.)&(wf.t<=t50+fitrange/2.)
        wf= wf[sel]
    initpars= dict(x0=t50, error_x0=1, N= intl, error_N=sqrt(intl), sigma=5, error_sigma=1,\
                   tau1= 70, error_tau1=1, tau2=5, error_tau2=1)
    limits= dict(limit_x0=(0,200), limit_N=(0,intl*5), limit_tau1=(10,200), limit_tau2=(0.1,100), limit_sigma=(0.1,100))
    initpars = dict(initpars.items() + limits.items())
    x2, mn = fit_gexp(wf.t, wf.p, print_level=0, **initpars)
    return x2, mn

# %%
def waveformfitset(dtpop, npe, tau, jittersigma, noise, apdmodel, binwidth, nfits, fitrange):
    results= []
    for i in xrange(nfits):
        pulse = event_pulse(dtpop, npe, tau, jittersigma, noise, apdmodel)
        wf = digiwaveform(pulse, binwidth, nprnd.uniform())
        x2, mn= waveformfit(wf, fitrange)
        results.append(mn.values)
    return results

# %%
# Test one fit
pulse = event_pulse(hexdata['baf2po9'].t, 1000, 0.9, 0.1, 0.0, pmslapd9mm)
wf = digiwaveform(pulse, binwidth=5.0, tshift=0.2)
x2, mn = waveformfit(wf, 100)

# %%
x2.draw(mn);
plt.xlabel('ns')
plt.savefig('../plots/waveform_fit_exp.pdf')

# %%
# Test another fit
wf2 = digiwaveform(pulse, binwidth=2.0, tshift=0.2)
x2, mn = waveformfit(wf2, 100)
x2.draw(mn);
plt.xlabel('ns')
plt.savefig('../plots/waveform_fit_exp2ns.pdf')

# %% [markdown]
# <h2>Start toys</h2>

# %%
nfits= 1000
binwidths= [1, 2, 3, 5, 7, 10]
npes = [300, 1000, 3000, 10000]
fitrange= 100
nprnd.seed(0)
for bw in binwidths:  
    for npe in npes:
        results= waveformfitset(hexdata['baf2po9'].t, npe= npe, tau= tau_baf2, jittersigma=0.1, noise=0.0, apdmodel= pmslapd9mm,
                                binwidth=bw, nfits=nfits, fitrange=fitrange)
        fn = '../data/timing/wffit_baf2po9_npe%d_bw%d_fr%d.p'%(npe,bw,fitrange)
        print fn
        pickle.dump(results, open(fn, 'wb'))
# Out:
# ../data/timing/wffit_baf2po9_npe300_bw1_fr100.p
# ../data/timing/wffit_baf2po9_npe1000_bw1_fr100.p
# ../data/timing/wffit_baf2po9_npe3000_bw1_fr100.p
# ../data/timing/wffit_baf2po9_npe10000_bw1_fr100.p
# ../data/timing/wffit_baf2po9_npe300_bw2_fr100.p
# ../data/timing/wffit_baf2po9_npe1000_bw2_fr100.p
# ../data/timing/wffit_baf2po9_npe3000_bw2_fr100.p
# ../data/timing/wffit_baf2po9_npe10000_bw2_fr100.p
# ../data/timing/wffit_baf2po9_npe300_bw3_fr100.p
# ../data/timing/wffit_baf2po9_npe1000_bw3_fr100.p
# ../data/timing/wffit_baf2po9_npe3000_bw3_fr100.p
# ../data/timing/wffit_baf2po9_npe10000_bw3_fr100.p
# ../data/timing/wffit_baf2po9_npe300_bw5_fr100.p
# ../data/timing/wffit_baf2po9_npe1000_bw5_fr100.p
# ../data/timing/wffit_baf2po9_npe3000_bw5_fr100.p
# ../data/timing/wffit_baf2po9_npe10000_bw5_fr100.p
# ../data/timing/wffit_baf2po9_npe300_bw7_fr100.p
# ../data/timing/wffit_baf2po9_npe1000_bw7_fr100.p
# ../data/timing/wffit_baf2po9_npe3000_bw7_fr100.p
# ../data/timing/wffit_baf2po9_npe10000_bw7_fr100.p
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-0c7bf02e77f8> in <module>()
#       7     for npe in npes:
#       8         results= waveformfitset(hexdata['baf2po9'].t, npe= npe, tau= tau_baf2, jittersigma=0.1, noise=0.0, apdmodel= pmslapd9mm,
# ----> 9                                 binwidth=bw, nfits=nfits, fitrange=fitrange)
#      10         fn = '../data/timing/wffit_baf2po9_npe%d_bw%d_fr%d.p'%(npe,bw,fitrange)
#      11         print fn
#
# <ipython-input-17-cf88ac976ea5> in waveformfitset(dtpop, npe, tau, jittersigma, noise, apdmodel, binwidth, nfits, fitrange)
#       4         pulse = event_pulse(dtpop, npe, tau, jittersigma, noise, apdmodel)
#       5         wf = digiwaveform(pulse, binwidth, nprnd.uniform())
# ----> 6         x2, mn= waveformfit(wf, fitrange)
#       7         results.append(mn.values)
#       8     return results
#
# <ipython-input-16-d7cfa781c483> in waveformfit(wf, fitrange)
#       5     '''
#       6     # t reaching half maximum, used for initial value of x0
# ----> 7     t50 = time_reach_threshold(wf.t, wf.p, 0.5)
#       8     tmax = wf.t[wf.p.argmax()]
#       9     # estimate integral
#
# /Users/chcheng/Work/mu2e/LightCollectionStudy/rayTraceNotebook/timing_utilities.pyc in time_reach_threshold(xt0, pulse, fthreshold)
#     299     if sel.sum()<3:
#     300         sel = [jt-1, jt, jt+1]
# --> 301     return interpolinear(threshold, xt[sel], prise[sel])
#     302
#     303
#
# IndexError: index 4 out of bounds 0<=index<4

# %%
nfits= 1000
binwidths= [10]
npes = [300, 1000, 3000, 10000]
fitrange= 100
nprnd.seed(0)
for bw in binwidths:  
    for npe in npes:
        results= waveformfitset(hexdata['baf2po9'].t, npe= npe, tau= tau_baf2, jittersigma=0.1, noise=0.0, apdmodel= pmslapd9mm,
                                binwidth=bw, nfits=nfits, fitrange=fitrange)
        fn = '../data/timing/wffit_baf2po9_npe%d_bw%d_fr%d.p'%(npe,bw,fitrange)
        print fn
        pickle.dump(results, open(fn, 'wb'))
# Out:
# ../data/timing/wffit_baf2po9_npe300_bw10_fr100.p
# ../data/timing/wffit_baf2po9_npe1000_bw10_fr100.p
# ../data/timing/wffit_baf2po9_npe3000_bw10_fr100.p
# ../data/timing/wffit_baf2po9_npe10000_bw10_fr100.p

# %%
s= [0,1,2]
s= s[:-1]
print s
s= s[1:]
print s
print len(s)
# Out:
# [0, 1]
# [1]
# 1

# %%
plt.plot(wf1.t, wf1.p, 'bo-')
plt.plot(wf2.t, wf2.p, 'rx-')

# %%
ts = tevent.t
ys = GExp2(ts, 30, 10, 50, 10, 400)
plt.plot(wf.t, wf.p, 'bo')
plt.plot(ts, ys, 'r-')

# %%
x2reg= Chi2Regression(GExp2, wf.t, wf.p)
m= Minuit(x2reg, print_level=1, x0=30, sigma=5, tau1= 50, tau2=10, N=500)
m.migrad()
m.hesse()
# Out:
# -c:2: InitialParamWarning: Parameter x0 is floating but does not have initial step size. Assume 1.
# -c:2: InitialParamWarning: Parameter sigma is floating but does not have initial step size. Assume 1.
# -c:2: InitialParamWarning: Parameter tau1 is floating but does not have initial step size. Assume 1.
# -c:2: InitialParamWarning: Parameter tau2 is floating but does not have initial step size. Assume 1.
# -c:2: InitialParamWarning: Parameter N is floating but does not have initial step size. Assume 1.
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 2527.37593109</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 414</td>
#                 <td title="Number of call in last migrad">NCALLS = 414</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 1.03765159407e-06</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 1e-05</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 1.0</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#jFgrhdGAVH').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>x0</td>
#                 <td>3.640635e+01</td>
#                 <td>9.942871e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>sigma</td>
#                 <td>8.811136e+00</td>
#                 <td>5.605376e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>tau1</td>
#                 <td>5.061171e+01</td>
#                 <td>1.338057e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>tau2</td>
#                 <td>4.507948e+00</td>
#                 <td>6.328074e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>N</td>
#                 <td>3.583488e+02</td>
#                 <td>1.306857e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="jFgrhdGAVH" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & x0 & 3.641e+01 & 9.943e-02 &  &  &  &  & \\
# \hline
# 2 & $\sigma$ & 8.811e+00 & 5.605e-02 &  &  &  &  & \\
# \hline
# 3 & tau1 & 5.061e+01 & 1.338e-01 &  &  &  &  & \\
# \hline
# 4 & tau2 & 4.508e+00 & 6.328e-01 &  &  &  &  & \\
# \hline
# 5 & N & 3.583e+02 & 1.307e+00 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#ddUMccIeMl').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>x0</td>
#                 <td>3.640635e+01</td>
#                 <td>9.945882e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>sigma</td>
#                 <td>8.811136e+00</td>
#                 <td>5.606290e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>tau1</td>
#                 <td>5.061171e+01</td>
#                 <td>1.338110e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>tau2</td>
#                 <td>4.507948e+00</td>
#                 <td>6.330167e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>N</td>
#                 <td>3.583488e+02</td>
#                 <td>1.307162e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="ddUMccIeMl" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & x0 & 3.641e+01 & 9.946e-02 &  &  &  &  & \\
# \hline
# 2 & $\sigma$ & 8.811e+00 & 5.606e-02 &  &  &  &  & \\
# \hline
# 3 & tau1 & 5.061e+01 & 1.338e-01 &  &  &  &  & \\
# \hline
# 4 & tau2 & 4.508e+00 & 6.330e-01 &  &  &  &  & \\
# \hline
# 5 & N & 3.583e+02 & 1.307e+00 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
#             <table>
#                 <tr>
#                     <td><a onclick="$('#ztVMaGDqmZ').toggle()" href="#">+</a></td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             x0
#             </div>
#             </div>
#             </td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             sigma
#             </div>
#             </div>
#             </td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             tau1
#             </div>
#             </div>
#             </td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             tau2
#             </div>
#             </div>
#             </td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             N
#             </div>
#             </div>
#             </td>
#
#                 </tr>
#
#             <tr>
#                 <td>x0</td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#                 <td style="background-color:rgb(232,151,134)">
#                 0.75
#                 </td>
#
#                 <td style="background-color:rgb(174,237,178)">
#                 0.12
#                 </td>
#
#                 <td style="background-color:rgb(250,125,121)">
#                 -0.94
#                 </td>
#
#                 <td style="background-color:rgb(224,164,141)">
#                 -0.66
#                 </td>
#
#             </tr>
#
#             <tr>
#                 <td>sigma</td>
#
#                 <td style="background-color:rgb(232,151,134)">
#                 0.75
#                 </td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#                 <td style="background-color:rgb(168,246,182)">
#                 -0.06
#                 </td>
#
#                 <td style="background-color:rgb(228,156,137)">
#                 -0.71
#                 </td>
#
#                 <td style="background-color:rgb(193,209,163)">
#                 -0.33
#                 </td>
#
#             </tr>
#
#             <tr>
#                 <td>tau1</td>
#
#                 <td style="background-color:rgb(174,237,178)">
#                 0.12
#                 </td>
#
#                 <td style="background-color:rgb(168,246,182)">
#                 -0.06
#                 </td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#                 <td style="background-color:rgb(193,209,163)">
#                 -0.33
#                 </td>
#
#                 <td style="background-color:rgb(232,151,134)">
#                 -0.75
#                 </td>
#
#             </tr>
#
#             <tr>
#                 <td>tau2</td>
#
#                 <td style="background-color:rgb(250,125,121)">
#                 -0.94
#                 </td>
#
#                 <td style="background-color:rgb(228,156,137)">
#                 -0.71
#                 </td>
#
#                 <td style="background-color:rgb(193,209,163)">
#                 -0.33
#                 </td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#                 <td style="background-color:rgb(238,143,130)">
#                 0.81
#                 </td>
#
#             </tr>
#
#             <tr>
#                 <td>N</td>
#
#                 <td style="background-color:rgb(224,164,141)">
#                 -0.66
#                 </td>
#
#                 <td style="background-color:rgb(193,209,163)">
#                 -0.33
#                 </td>
#
#                 <td style="background-color:rgb(232,151,134)">
#                 -0.75
#                 </td>
#
#                 <td style="background-color:rgb(238,143,130)">
#                 0.81
#                 </td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#             </tr>
#             </table>
#
#             <pre id="ztVMaGDqmZ" style="display:none;">
#             <textarea rows="19" cols="50" onclick="this.select()" readonly>%\usepackage[table]{xcolor} % include this for color
# %\usepackage{rotating} % include this for rotate header
# %\documentclass[xcolor=table]{beamer} % for beamer
# \begin{tabular}{|c|c|c|c|c|c|}
# \hline
# \rotatebox{90}{} & \rotatebox{90}{x0} & \rotatebox{90}{$\sigma$} & \rotatebox{90}{tau1} & \rotatebox{90}{tau2} & \rotatebox{90}{N}\\
# \hline
# x0 & \cellcolor[RGB]{255,117,117} 1.00 & \cellcolor[RGB]{232,151,134} 0.75 & \cellcolor[RGB]{174,237,178} 0.12 & \cellcolor[RGB]{250,125,121} -0.94 & \cellcolor[RGB]{224,164,141} -0.66\\
# \hline
# $\sigma$ & \cellcolor[RGB]{232,151,134} 0.75 & \cellcolor[RGB]{255,117,117} 1.00 & \cellcolor[RGB]{168,246,182} -0.06 & \cellcolor[RGB]{228,156,137} -0.71 & \cellcolor[RGB]{193,209,163} -0.33\\
# \hline
# tau1 & \cellcolor[RGB]{174,237,178} 0.12 & \cellcolor[RGB]{168,246,182} -0.06 & \cellcolor[RGB]{255,117,117} 1.00 & \cellcolor[RGB]{193,209,163} -0.33 & \cellcolor[RGB]{232,151,134} -0.75\\
# \hline
# tau2 & \cellcolor[RGB]{250,125,121} -0.94 & \cellcolor[RGB]{228,156,137} -0.71 & \cellcolor[RGB]{193,209,163} -0.33 & \cellcolor[RGB]{255,117,117} 1.00 & \cellcolor[RGB]{238,143,130} 0.81\\
# \hline
# N & \cellcolor[RGB]{224,164,141} -0.66 & \cellcolor[RGB]{193,209,163} -0.33 & \cellcolor[RGB]{232,151,134} -0.75 & \cellcolor[RGB]{238,143,130} 0.81 & \cellcolor[RGB]{255,117,117} 1.00\\
# \hline
# \end{tabular}</textarea>
#             </pre>
# [{'is_const': False, 'name': 'x0', 'has_limits': False, 'value': 36.40635175796696, 'number': 0L, 'has_lower_limit': False, 'upper_limit': 0.0, 'lower_limit': 0.0, 'has_upper_limit': False, 'error': 0.09945882376038322, 'is_fixed': False},
#  {'is_const': False, 'name': 'sigma', 'has_limits': False, 'value': 8.811135866627067, 'number': 1L, 'has_lower_limit': False, 'upper_limit': 0.0, 'lower_limit': 0.0, 'has_upper_limit': False, 'error': 0.05606289829550171, 'is_fixed': False},
#  {'is_const': False, 'name': 'tau1', 'has_limits': False, 'value': 50.611713282138794, 'number': 2L, 'has_lower_limit': False, 'upper_limit': 0.0, 'lower_limit': 0.0, 'has_upper_limit': False, 'error': 0.13381104110802322, 'is_fixed': False},
#  {'is_const': False, 'name': 'tau2', 'has_limits': False, 'value': 4.507948182544571, 'number': 3L, 'has_lower_limit': False, 'upper_limit': 0.0, 'lower_limit': 0.0, 'has_upper_limit': False, 'error': 0.63301665347286, 'is_fixed': False},
#  {'is_const': False, 'name': 'N', 'has_limits': False, 'value': 358.34882189455146, 'number': 4L, 'has_lower_limit': False, 'upper_limit': 0.0, 'lower_limit': 0.0, 'has_upper_limit': False, 'error': 1.3071623682599574, 'is_fixed': False}]

# %%
x2reg.draw(m);

# %%
x2reg, m= fit_pulse_simple(tevent.t, tevent.p, None, x0=20, tauR=10, tauD=20, A=100)
# Out:
# fit_utilities.py:51: InitialParamWarning: Parameter tauR is floating but does not have initial step size. Assume 1.
#   m= Minuit(x2reg, **kwargs)
# fit_utilities.py:51: InitialParamWarning: Parameter tauD is floating but does not have initial step size. Assume 1.
#   m= Minuit(x2reg, **kwargs)
# fit_utilities.py:51: InitialParamWarning: Parameter A is floating but does not have initial step size. Assume 1.
#   m= Minuit(x2reg, **kwargs)
# fit_utilities.py:51: InitialParamWarning: Parameter x0 is floating but does not have initial step size. Assume 1.
#   m= Minuit(x2reg, **kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 371583.596641</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 216</td>
#                 <td title="Number of call in last migrad">NCALLS = 216</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 4.05248502424e-06</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 1e-05</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 1.0</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#guhbSibkCE').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>tauR</td>
#                 <td>1.254526e+01</td>
#                 <td>1.170856e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>tauD</td>
#                 <td>4.583760e+01</td>
#                 <td>2.592274e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>A</td>
#                 <td>1.712698e+04</td>
#                 <td>3.606322e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>x0</td>
#                 <td>2.714657e+01</td>
#                 <td>4.456093e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="guhbSibkCE" style="display:none;">
#             <textarea rows="14" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & tauR & 1.255e+01 & 1.171e-02 &  &  &  &  & \\
# \hline
# 2 & tauD & 4.584e+01 & 2.592e-02 &  &  &  &  & \\
# \hline
# 3 & A & 1.713e+04 & 3.606e+00 &  &  &  &  & \\
# \hline
# 4 & x0 & 2.715e+01 & 4.456e-03 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#KHdYsuoyzu').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>tauR</td>
#                 <td>1.254526e+01</td>
#                 <td>1.170856e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>tauD</td>
#                 <td>4.583760e+01</td>
#                 <td>2.592274e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>A</td>
#                 <td>1.712698e+04</td>
#                 <td>3.606322e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>x0</td>
#                 <td>2.714657e+01</td>
#                 <td>4.456093e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="KHdYsuoyzu" style="display:none;">
#             <textarea rows="14" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & tauR & 1.255e+01 & 1.171e-02 &  &  &  &  & \\
# \hline
# 2 & tauD & 4.584e+01 & 2.592e-02 &  &  &  &  & \\
# \hline
# 3 & A & 1.713e+04 & 3.606e+00 &  &  &  &  & \\
# \hline
# 4 & x0 & 2.715e+01 & 4.456e-03 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
#             <table>
#                 <tr>
#                     <td><a onclick="$('#fHODqsunYw').toggle()" href="#">+</a></td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             tauR
#             </div>
#             </div>
#             </td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             tauD
#             </div>
#             </div>
#             </td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             A
#             </div>
#             </div>
#             </td>
#
#             <td>
#             <div style="width:20px;position:relative; width: -moz-fit-content;">
#             <div style="display:inline-block;-webkit-writing-mode:vertical-rl;-moz-writing-mode: vertical-rl;writing-mode: vertical-rl;">
#             x0
#             </div>
#             </div>
#             </td>
#
#                 </tr>
#
#             <tr>
#                 <td>tauR</td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#                 <td style="background-color:rgb(236,145,131)">
#                 -0.80
#                 </td>
#
#                 <td style="background-color:rgb(197,203,160)">
#                 -0.37
#                 </td>
#
#                 <td style="background-color:rgb(212,181,149)">
#                 -0.54
#                 </td>
#
#             </tr>
#
#             <tr>
#                 <td>tauD</td>
#
#                 <td style="background-color:rgb(236,145,131)">
#                 -0.80
#                 </td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#                 <td style="background-color:rgb(226,160,139)">
#                 0.68
#                 </td>
#
#                 <td style="background-color:rgb(182,226,172)">
#                 0.20
#                 </td>
#
#             </tr>
#
#             <tr>
#                 <td>A</td>
#
#                 <td style="background-color:rgb(197,203,160)">
#                 -0.37
#                 </td>
#
#                 <td style="background-color:rgb(226,160,139)">
#                 0.68
#                 </td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#                 <td style="background-color:rgb(167,249,183)">
#                 -0.04
#                 </td>
#
#             </tr>
#
#             <tr>
#                 <td>x0</td>
#
#                 <td style="background-color:rgb(212,181,149)">
#                 -0.54
#                 </td>
#
#                 <td style="background-color:rgb(182,226,172)">
#                 0.20
#                 </td>
#
#                 <td style="background-color:rgb(167,249,183)">
#                 -0.04
#                 </td>
#
#                 <td style="background-color:rgb(255,117,117)">
#                 1.00
#                 </td>
#
#             </tr>
#             </table>
#
#             <pre id="fHODqsunYw" style="display:none;">
#             <textarea rows="17" cols="50" onclick="this.select()" readonly>%\usepackage[table]{xcolor} % include this for color
# %\usepackage{rotating} % include this for rotate header
# %\documentclass[xcolor=table]{beamer} % for beamer
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# \rotatebox{90}{} & \rotatebox{90}{tauR} & \rotatebox{90}{tauD} & \rotatebox{90}{A} & \rotatebox{90}{x0}\\
# \hline
# tauR & \cellcolor[RGB]{255,117,117} 1.00 & \cellcolor[RGB]{236,145,131} -0.80 & \cellcolor[RGB]{197,203,160} -0.37 & \cellcolor[RGB]{212,181,149} -0.54\\
# \hline
# tauD & \cellcolor[RGB]{236,145,131} -0.80 & \cellcolor[RGB]{255,117,117} 1.00 & \cellcolor[RGB]{226,160,139} 0.68 & \cellcolor[RGB]{182,226,172} 0.20\\
# \hline
# A & \cellcolor[RGB]{197,203,160} -0.37 & \cellcolor[RGB]{226,160,139} 0.68 & \cellcolor[RGB]{255,117,117} 1.00 & \cellcolor[RGB]{167,249,183} -0.04\\
# \hline
# x0 & \cellcolor[RGB]{212,181,149} -0.54 & \cellcolor[RGB]{182,226,172} 0.20 & \cellcolor[RGB]{167,249,183} -0.04 & \cellcolor[RGB]{255,117,117} 1.00\\
# \hline
# \end{tabular}</textarea>
#             </pre>

# %%
x2reg.draw(m);

# %%
plt.plot(tb, hist, 'bo', ms=1)
plt.plot(tevent.t, tevent.p*200)

# %%
plt.plot(tb, hist-tevent.p*200, 'bo')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-622f72d349d0> in <module>()
# ----> 1 plt.plot(tb, hist-tevent.p*200, 'bo')
#
# ValueError: operands could not be broadcast together with shapes (20) (3991)

# %% [markdown]
# <h3>SL APD 9mm pulse model</h3>

# %%
fig= plt.figure(figsize=(12,3.5))
ax= fig.add_subplot(131)
draw_one_set(ax, hexdata['baf2po9'].t, tau_baf2, npe_baf2, pmslapd9mm, 'BaF2')
ax= fig.add_subplot(132)
draw_one_set(ax, hexdata['lysopo9'].t, tau_lyso, npe_lyso, pmslapd9mm, 'LYSO')
ax= fig.add_subplot(133)
draw_one_set(ax, hexdata['csipo9'].t, tau_csi, npe_csi, pmslapd9mm, 'CsI')

# %% [markdown]
# <h3>SL APD 3mm pulse model</h3>

# %%
fig= plt.figure(figsize=(12,3.5))
ax= fig.add_subplot(131)
draw_one_set(ax, hexdata['baf2po3'].t, tau_baf2, npe_baf2, pmslapd3mm, 'BaF2')
ax= fig.add_subplot(132)
draw_one_set(ax, hexdata['lysopo3'].t, tau_lyso, npe_lyso, pmslapd3mm, 'LYSO')
ax= fig.add_subplot(133)
draw_one_set(ax, hexdata['csipo3'].t, tau_csi, npe_csi, pmslapd3mm, 'CsI')

# %% [markdown]
# <h3>Standard APD 9mm pulse mode </h3>

# %%
fig= plt.figure(figsize=(12,3.5))
ax= fig.add_subplot(131)
draw_one_set(ax, hexdata['baf2po9'].t, tau_baf2, npe_baf2, pmstdapd9mm, 'BaF2')
ax= fig.add_subplot(132)
draw_one_set(ax, hexdata['lysopo9'].t, tau_lyso, npe_lyso, pmstdapd9mm, 'LYSO')
ax= fig.add_subplot(133)
draw_one_set(ax, hexdata['csipo9'].t, tau_csi, npe_csi, pmstdapd9mm, 'CsI')

# %% [markdown]
# <h2>Timing precision</h2>
#
# Study the event timing precision for three crystals, three photodetector pulse models, and several different numbers of photoelectrons. For each event (accumulation of all photoelectrons), the timing is found by fitting a line around the point where the pulse height is closest to the threshold, and then solving the time at the threshold. The range of the linear fit is 10 points, which corresponds to 2.5 ns.
#
# The threshold is set at 10% of the maximum of each event.

# %%
fthreshold = 0.1

# %%
pelist = [10, 30, 100, 300, 1000, 3000, 10000, 30000]
staudict = dict(baf2= tau_baf2, lyso= tau_lyso, csi= tau_csi)
apdlist = [pmslapd9mm, pmslapd3mm, pmstdapd9mm]
apdnames = ['SL-APD9mm', 'SL-APD3mm', 'Std-APD9mm']

# %%
result= {}
for mat in ['lyso','baf2','csi']:
    for sur in ['po','ra']:
        for sd, apdname, apdmodel in zip(['9','3','9'],apdnames,apdlist):
            key = mat+sur+sd
            print key, apdname,
            tpres = []
            tpres_err = []
            dtpop = hexdata[key]
            for npe in pelist:
                print npe,
                rand.seed(0)
                tot= timing_samples(dtpop.t, npe, staudict[mat], jittersigma= 0.1, pulsemodel= apdmodel,
                                    noise=0, fthreshold= fthreshold, n= 1000)
                rms= np.sqrt(tot.var())
                tpres.append(rms)
                tpres_err.append(rms/np.sqrt(2*len(tot)))
            print
            rkey= key+':'+apdname
            result[rkey]= np.array(tpres)
            result[rkey+'_err']= np.array(tpres_err)
# Out:
# lysopo9 SL-APD9mm 10
# 30
# 100
# 300
# 1000
# 3000
# 10000
# 30000
# lysopo3 SL-APD3mm 10
# 30
# 100
# 300
# 1000
# 3000
# 10000
# 30000
# lysopo9 Std-APD9mm 10
# 30
# 100
# 300
# 1000
# 3000
# 10000
# 30000
# lysora9 SL-APD9mm 10
# 30
# 100
# 300
# 1000
# 3000
# 10000
# 30000
# lysora3 SL-APD3mm 10
# 30
# 100
# 300
# 1000
# 3000
# 10000
# 30000
# lysora9 Std-APD9mm 10
# 30
# 100
# 300
# 1000
# 3000
# 10000
# 30000
# baf2po9 SL-APD9mm 10
# 30
# 100
# 300
# 1000
# 3000
# 10000
# 30000
# baf2po3 SL-APD3mm 10
# 30
# 100
# 300
# 1000
# 3000
# 10000
# 30000
# baf2po9 Std-APD9mm 10
# 30
# 100
# 300
# 1000
# 3000
# 10000
# 30000
# baf2ra9 SL-APD9mm 10
# 30
# 100
# 300
# 1000
# 3000
# 10000
# 30000
# baf2ra3 SL-APD3mm 10
# 30
# 100
# 300
# 1000
# 3000
# 10000
# 30000
# baf2ra9 Std-APD9mm 10
# 30
# 100
# 300
# 1000
# 3000
# 10000
# 30000
# csipo9 SL-APD9mm 10
# 30
# 100
# 300
# 1000
# 3000
# 10000
# 30000
# csipo3 SL-APD3mm 10
# 30
# 100
# 300
# 1000
# 3000
# 10000
# 30000
# csipo9 Std-APD9mm 10
# 30
# 100
# 300
# 1000
# 3000
# 10000
# 30000
# csira9 SL-APD9mm 10
# 30
# 100
# 300
# 1000
# 3000
# 10000
# 30000
# csira3 SL-APD3mm 10
# 30
# 100
# 300
# 1000
# 3000
# 10000
# 30000
# csira9 Std-APD9mm 10
# 30
# 100
# 300
# 1000
# 3000
# 10000
# 30000

# %%
result['npelist'] = pelist

# %%
###pickle.dump(result, open('../data/timing/tprecision_hex_preamp_geocolls2.p', 'wb'))

# %%
result.keys()
# Out:
# ['csira3:SL-APD3mm',
#  'lysopo3:SL-APD3mm_err',
#  'lysora9:Std-APD9mm',
#  'csira9:Std-APD9mm',
#  'baf2po3:SL-APD3mm_err',
#  'baf2po9:SL-APD9mm',
#  'lysora9:SL-APD9mm_err',
#  'lysora9:Std-APD9mm_err',
#  'csipo9:Std-APD9mm',
#  'csira3:SL-APD3mm_err',
#  'csipo3:SL-APD3mm_err',
#  'lysora9:SL-APD9mm',
#  'csipo9:SL-APD9mm_err',
#  'csira9:SL-APD9mm_err',
#  'lysora3:SL-APD3mm_err',
#  'csipo9:SL-APD9mm',
#  'lysopo9:SL-APD9mm',
#  'csipo9:Std-APD9mm_err',
#  'baf2ra3:SL-APD3mm_err',
#  'lysora3:SL-APD3mm',
#  'baf2ra9:Std-APD9mm_err',
#  'csira9:Std-APD9mm_err',
#  'lysopo3:SL-APD3mm',
#  'lysopo9:Std-APD9mm',
#  'csipo3:SL-APD3mm',
#  'lysopo9:SL-APD9mm_err',
#  'csira9:SL-APD9mm',
#  'baf2po9:Std-APD9mm_err',
#  'baf2ra9:SL-APD9mm',
#  'baf2ra9:SL-APD9mm_err',
#  'baf2ra9:Std-APD9mm',
#  'baf2po9:SL-APD9mm_err',
#  'baf2po9:Std-APD9mm',
#  'baf2ra3:SL-APD3mm',
#  'npelist',
#  'baf2po3:SL-APD3mm',
#  'lysopo9:Std-APD9mm_err']

# %%
mn.print_param()
# Out:
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#FRuKzIRjRr').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>x0</td>
#                 <td>3.227106e+01</td>
#                 <td>3.620590e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>sigma</td>
#                 <td>6.999310e+00</td>
#                 <td>3.492706e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>tau1</td>
#                 <td>2.953193e+01</td>
#                 <td>2.405508e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>tau2</td>
#                 <td>1.546759e+01</td>
#                 <td>1.382557e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>N</td>
#                 <td>1.170427e+02</td>
#                 <td>1.525983e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="FRuKzIRjRr" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & x0 & 3.227e+01 & 3.621e-01 &  &  &  &  & \\
# \hline
# 2 & $\sigma$ & 6.999e+00 & 3.493e-01 &  &  &  &  & \\
# \hline
# 3 & tau1 & 2.953e+01 & 2.406e-01 &  &  &  &  & \\
# \hline
# 4 & tau2 & 1.547e+01 & 1.383e-01 &  &  &  &  & \\
# \hline
# 5 & N & 1.170e+02 & 1.526e+00 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
